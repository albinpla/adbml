# %%
import pandas as pd
import nltk
import re
# from collections import Counter
# lis =()
lis = []
t = pd.read_csv("./datasets/dmoz0409_Arts_test.csv")
# print (t.ix[:,1:])
str_url = (t.ix[:,1:2])
str_class = (t.ix[:,2:])

urls = str_url.to_string(index = False)
# clas = str_class.to_string(index = False)
clas = str_class.values.tolist()
cleaned_urls = []
# print(clas)
myiter = iter(clas)
list_urls = urls.split('\n')
for row in list_urls:
    try:
        url_clas = next(myiter)
    except Exception as e:
        pass
    # print(type(row))
    nrow = re.sub('[\s!@#$+_.\-/:=&?~\d]',' ', row)
    # printpass)
    # tokens = nltk.word_tokenize(nrow)
    # print(tokens)
    # fourgrams=nltk.collocations.QuadgramCollocationFinder.from_words(tokens)
    # for fourgram, freq in fourgrams.ngram_fd.items():
        # print (fourgram)
    n = 4
    fourgrams = nltk.ngrams(nrow.split(), n)
    # forgrams = filter(None,list(fourgrams))
    # forgrams = [list(x) for x in fourgrams]
    # forgrams = list(fourgrams)
    # if forgrams != []:
    # if fourgrams != []:
        # print(forgrams)
        # lis.append(next(myiter))
        # lis.append(forgrams)
        # lis = lis + tuple(next(myiter))
        # lis = lis + tuple(fourgrams)
    for grams in fourgrams:
      # nlist = list(grams)
      url_str = ','.join(grams)
      print( url_str,',',url_clas[0])
    # cleaned_urls.append(nrow)
    # row = str(row)
    # print(nrow)
    # l = row.split('.').split('-').split('/').split('_').split('+')
    # string = "".join(l)
    # print (string)
# print(cleaned_urls)
# print(lis)

# sentence = 'this is a foo bar sentences and i want to ngramize it'
# n = 4
# fourgrams = ngrams(nrow.split(), n)
# for grams in fourgrams:
#   print (grams)
# print (str(fourgrams))
# Out:
# http,us,imdb,com , ['NonArts']
# us,imdb,com,name , ['NonArts']
# imdb,com,name,nm , ['NonArts']
# http,ersson,sustainabilitylane,com , ['NonArts']
# ersson,sustainabilitylane,com,rainwatr , ['NonArts']
# sustainabilitylane,com,rainwatr,htm , ['NonArts']
# http,www,asalv,org , ['NonArts']
# http,www,wildwoodlsc,org , ['NonArts']
# http,www,angelfire,com , ['Arts']
# www,angelfire,com,nc , ['Arts']
# angelfire,com,nc,lbell , ['Arts']
# http,www,tvguide,com , ['NonArts']
# www,tvguide,com,movies , ['NonArts']
# tvguide,com,movies,kissed , ['NonArts']
# http,www,bodley,ox , ['NonArts']
# www,bodley,ox,ac , ['NonArts']
# bodley,ox,ac,uk , ['NonArts']
# ox,ac,uk,guides , ['NonArts']
# ac,uk,guides,maps , ['NonArts']
# uk,guides,maps,maplink , ['NonArts']
# http,www,breastfriends,com , ['NonArts']
# http,www,facstaff,bucknell , ['Arts']
# www,facstaff,bucknell,edu , ['Arts']
# facstaff,bucknell,edu,rbeard , ['Arts']
# bucknell,edu,rbeard,hippo , ['Arts']
# http,imdb,com,title , ['NonArts']
# imdb,com,title,tt , ['NonArts']
# http,www,linuxchix,org , ['NonArts']
# http,en,wikipedia,org , ['NonArts']
# en,wikipedia,org,wiki , ['NonArts']
# wikipedia,org,wiki,thomas , ['NonArts']
# org,wiki,thomas,sowell , ['NonArts']
# http,www,cortlandny,com , ['NonArts']
# www,cortlandny,com,zonta , ['NonArts']
# http,www,glasgow,ky , ['NonArts']
# www,glasgow,ky,com , ['NonArts']
# glasgow,ky,com,fye , ['NonArts']
# ky,com,fye,ms , ['NonArts']
# com,fye,ms,fye , ['NonArts']
# fye,ms,fye,colonial , ['NonArts']
# http,www,screensaverheaven,com , ['NonArts']
# http,www,designercollectibles,com , ['NonArts']
# http,www,telus,net , ['NonArts']
# www,telus,net,pat , ['NonArts']
# telus,net,pat,bill , ['NonArts']
# net,pat,bill,hsbc , ['NonArts']
# http,www,journals,uchicago , ['NonArts']
# www,journals,uchicago,edu , ['NonArts']
# journals,uchicago,edu,cer , ['NonArts']
# uchicago,edu,cer,home , ['NonArts']
# edu,cer,home,html , ['NonArts']
# http,www,plantatlas,usf , ['Arts']
# www,plantatlas,usf,edu , ['Arts']
# plantatlas,usf,edu,main , ['Arts']
# usf,edu,main,asp , ['Arts']
# edu,main,asp,plantid , ['Arts']
# http,community,livejournal,com , ['NonArts']
# community,livejournal,com,yalitlovers , ['NonArts']
# http,www,jal,cc , ['NonArts']
# www,jal,cc,il , ['NonArts']
# jal,cc,il,us , ['NonArts']
# http,www,com,games , ['NonArts']
# www,com,games,com , ['NonArts']
# http,www,piratesofthecaribbean,com , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,dobo , ['NonArts']
# geocities,com,dobo,music , ['NonArts']
# com,dobo,music,html , ['NonArts']
# http,www,flickr,com , ['NonArts']
# www,flickr,com,groups , ['NonArts']
# flickr,com,groups,trespassing , ['NonArts']
# http,www,old,babes , ['NonArts']
# www,old,babes,sex , ['NonArts']
# old,babes,sex,com , ['NonArts']
# babes,sex,com,fine , ['NonArts']
# sex,com,fine,old , ['NonArts']
# com,fine,old,ladies , ['NonArts']
# http,ds,gamespy,com , ['NonArts']
# ds,gamespy,com,nintendo , ['NonArts']
# gamespy,com,nintendo,ds , ['NonArts']
# com,nintendo,ds,cradle , ['NonArts']
# nintendo,ds,cradle,of , ['NonArts']
# ds,cradle,of,rome , ['NonArts']
# http,www,michaelmonaco,com , ['NonArts']
# www,michaelmonaco,com,home , ['NonArts']
# michaelmonaco,com,home,asp , ['NonArts']
# http,www,danfissel,com , ['NonArts']
# http,www,giftbasketcreations,com , ['NonArts']
# http,www,vjsuper,org , ['NonArts']
# http,www,sourcewireless,com , ['NonArts']
# http,www,freewebs,com , ['NonArts']
# www,freewebs,com,yucaipacrosscountry , ['NonArts']
# http,www,update,uu , ['NonArts']
# www,update,uu,se , ['NonArts']
# update,uu,se,fbendz , ['NonArts']
# uu,se,fbendz,pseudo , ['NonArts']
# http,www,london,edu , ['NonArts']
# www,london,edu,library , ['NonArts']
# london,edu,library,html , ['NonArts']
# http,www,dollhousesbyliz,com , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,cheddargoddess , ['NonArts']
# http,packages,gentoo,org , ['NonArts']
# http,www,cornhuskersign,com , ['NonArts']
# http,www,jaggedpath,com , ['NonArts']
# http,handsindirt,blogspot,com , ['NonArts']
# http,www,acekvale,com , ['NonArts']
# http,www,infratech,ltd , ['NonArts']
# www,infratech,ltd,uk , ['NonArts']
# http,www,caninecancerawareness,org , ['NonArts']
# http,www,kckern,com , ['NonArts']
# http,www,john,bauer , ['Arts']
# www,john,bauer,com , ['Arts']
# john,bauer,com,dalai , ['Arts']
# bauer,com,dalai,lama , ['Arts']
# com,dalai,lama,htm , ['Arts']
# http,es,geocities,com , ['NonArts']
# es,geocities,com,suedeweb , ['NonArts']
# http,www,savethehorses,org , ['NonArts']
# http,www,o,a , ['NonArts']
# www,o,a,com , ['NonArts']
# o,a,com,dtalk , ['NonArts']
# a,com,dtalk,htm , ['NonArts']
# http,www,sharieckert,net , ['NonArts']
# http,www,troop,homestead , ['NonArts']
# www,troop,homestead,com , ['NonArts']
# troop,homestead,com,home , ['NonArts']
# homestead,com,home,html , ['NonArts']
# http,www,mrprobability,com , ['Arts']
# http,jam,canoe,ca , ['NonArts']
# jam,canoe,ca,movies , ['NonArts']
# canoe,ca,movies,artists , ['NonArts']
# ca,movies,artists,c , ['NonArts']
# movies,artists,c,campion , ['NonArts']
# artists,c,campion,j , ['NonArts']
# http,www,mediatek,aei , ['NonArts']
# www,mediatek,aei,com , ['NonArts']
# http,www,sciencedaily,com , ['NonArts']
# www,sciencedaily,com,releases , ['NonArts']
# http,www,radiopharmacy,info , ['NonArts']
# http,answering,islam,org , ['NonArts']
# answering,islam,org,index , ['NonArts']
# islam,org,index,a , ['NonArts']
# org,index,a,abraham , ['NonArts']
# index,a,abraham,html , ['NonArts']
# http,www,godiplomats,com , ['Arts']
# www,godiplomats,com,sports , ['Arts']
# godiplomats,com,sports,m , ['Arts']
# com,sports,m,baskbl , ['Arts']
# sports,m,baskbl,index , ['Arts']
# http,www,mcardleschools,com , ['NonArts']
# http,www,tamilsweb,com , ['NonArts']
# http,www,haverford,edu , ['NonArts']
# www,haverford,edu,athletics , ['NonArts']
# haverford,edu,athletics,cricket , ['NonArts']
# http,www,ecn,cz , ['NonArts']
# www,ecn,cz,temelin , ['NonArts']
# http,persiankittens,net,doublejforme , ['NonArts']
# http,www,ultrainvitations,com , ['NonArts']
# http,www,wku,edu , ['NonArts']
# www,wku,edu,sally , ['NonArts']
# wku,edu,sally,kuhlenschmidt , ['NonArts']
# edu,sally,kuhlenschmidt,psycar , ['NonArts']
# http,www,benchmarkit,com , ['NonArts']
# www,benchmarkit,com,benchmark , ['NonArts']
# benchmarkit,com,benchmark,aboutus , ['NonArts']
# com,benchmark,aboutus,htm , ['NonArts']
# http,www,collegeart,org , ['Arts']
# http,www,classical,net , ['NonArts']
# www,classical,net,music , ['NonArts']
# classical,net,music,comp , ['NonArts']
# net,music,comp,lst , ['NonArts']
# music,comp,lst,acc , ['NonArts']
# comp,lst,acc,se , ['NonArts']
# http,www,labservicetech,com , ['NonArts']
# http,www,ctan,org , ['NonArts']
# www,ctan,org,tex , ['NonArts']
# ctan,org,tex,archive , ['NonArts']
# org,tex,archive,macros , ['NonArts']
# tex,archive,macros,latex , ['NonArts']
# archive,macros,latex,c , ['NonArts']
# http,www,fao,org , ['NonArts']
# www,fao,org,countryprofiles , ['NonArts']
# http,www,christchurchcathedral,bc , ['NonArts']
# www,christchurchcathedral,bc,ca , ['NonArts']
# http,www,sniksnak,com , ['Arts']
# www,sniksnak,com,k , ['Arts']
# sniksnak,com,k,chang , ['Arts']
# com,k,chang,html , ['Arts']
# http,us,imdb,com , ['Arts']
# us,imdb,com,title , ['Arts']
# imdb,com,title,tt , ['Arts']
# http,www,joesairbrushing,com , ['Arts']
# http,abc,go,com , ['NonArts']
# abc,go,com,primetime , ['NonArts']
# go,com,primetime,dancing , ['NonArts']
# com,primetime,dancing,bios , ['NonArts']
# primetime,dancing,bios,max , ['NonArts']
# http,www,rebelscum,com , ['NonArts']
# http,www,dataage,com , ['Arts']
# http,groups,yahoo,com , ['NonArts']
# groups,yahoo,com,group , ['NonArts']
# yahoo,com,group,hugs , ['NonArts']
# com,group,hugs,and , ['NonArts']
# group,hugs,and,stitches , ['NonArts']
# http,www,gla,ac , ['NonArts']
# www,gla,ac,uk , ['NonArts']
# gla,ac,uk,faculties , ['NonArts']
# ac,uk,faculties,vet , ['NonArts']
# http,www,brianlynchmd,com , ['NonArts']
# http,www,zygo,usa , ['NonArts']
# www,zygo,usa,com , ['NonArts']
# http,www,accd,edu , ['NonArts']
# www,accd,edu,sac , ['NonArts']
# accd,edu,sac,gov , ['NonArts']
# edu,sac,gov,govhome , ['NonArts']
# sac,gov,govhome,index , ['NonArts']
# gov,govhome,index,htm , ['NonArts']
# http,www,revelle,ca , ['Arts']
# http,www,zimfamilycockers,com , ['NonArts']
# www,zimfamilycockers,com,kcpr , ['NonArts']
# zimfamilycockers,com,kcpr,html , ['NonArts']
# http,www,osmonics,com , ['NonArts']
# www,osmonics,com,products , ['NonArts']
# osmonics,com,products,page , ['NonArts']
# com,products,page,htm , ['NonArts']
# http,www,biddleconsulting,com , ['NonArts']
# http,www,nothrow,com , ['NonArts']
# http,www,noptel,fi , ['NonArts']
# www,noptel,fi,eng , ['NonArts']
# noptel,fi,eng,index , ['NonArts']
# fi,eng,index,html , ['NonArts']
# http,www,newadvent,org , ['NonArts']
# www,newadvent,org,cathen , ['NonArts']
# newadvent,org,cathen,d , ['NonArts']
# org,cathen,d,htm , ['NonArts']
# http,www,nosca,freeserve , ['NonArts']
# www,nosca,freeserve,co , ['NonArts']
# nosca,freeserve,co,uk , ['NonArts']
# http,www,fileplanet,com , ['NonArts']
# www,fileplanet,com,section , ['NonArts']
# fileplanet,com,section,sta , ['NonArts']
# http,www,rainfordmodels,co , ['NonArts']
# www,rainfordmodels,co,uk , ['NonArts']
# http,www,i,e , ['NonArts']
# www,i,e,i , ['NonArts']
# i,e,i,com , ['NonArts']
# http,www,webalice,it , ['NonArts']
# www,webalice,it,fulvio , ['NonArts']
# webalice,it,fulvio,peruggi , ['NonArts']
# it,fulvio,peruggi,public , ['NonArts']
# fulvio,peruggi,public,p , ['NonArts']
# http,web,telia,com , ['Arts']
# web,telia,com,u , ['Arts']
# telia,com,u,home , ['Arts']
# com,u,home,html , ['Arts']
# http,www,gamespot,com , ['NonArts']
# www,gamespot,com,ps , ['NonArts']
# gamespot,com,ps,sports , ['NonArts']
# com,ps,sports,sammysosasso , ['NonArts']
# http,www,ctfa,org , ['NonArts']
# http,www,gilwell,com , ['NonArts']
# www,gilwell,com,jashs , ['NonArts']
# http,www,dm,net , ['NonArts']
# www,dm,net,dream , ['NonArts']
# dm,net,dream,index , ['NonArts']
# net,dream,index,shtml , ['NonArts']
# http,ga,op,royalrangers , ['NonArts']
# ga,op,royalrangers,netfirms , ['NonArts']
# op,royalrangers,netfirms,com , ['NonArts']
# http,www,reesetipis,com , ['NonArts']
# http,www,billybear,kids , ['Arts']
# www,billybear,kids,com , ['Arts']
# billybear,kids,com,desktop , ['Arts']
# kids,com,desktop,val , ['Arts']
# com,desktop,val,wall , ['Arts']
# http,www,hf,ntnu , ['NonArts']
# www,hf,ntnu,no , ['NonArts']
# hf,ntnu,no,engelsk , ['NonArts']
# ntnu,no,engelsk,shakespeare , ['NonArts']
# no,engelsk,shakespeare,jews , ['NonArts']
# http,users,cybercity,dk , ['NonArts']
# users,cybercity,dk,cfs , ['NonArts']
# cybercity,dk,cfs,uk , ['NonArts']
# dk,cfs,uk,index , ['NonArts']
# cfs,uk,index,htm , ['NonArts']
# http,www,coalvillerugbyclubmj,co , ['NonArts']
# www,coalvillerugbyclubmj,co,uk , ['NonArts']
# http,www,gamespot,com , ['NonArts']
# www,gamespot,com,pc , ['NonArts']
# gamespot,com,pc,adventure , ['NonArts']
# com,pc,adventure,spqrtheem , ['NonArts']
# http,www,max,de , ['NonArts']
# www,max,de,erotik , ['NonArts']
# http,www,tvcc,edu , ['NonArts']
# http,www,cambellandgardiner,com , ['NonArts']
# http,www,lifelong,tcu , ['NonArts']
# www,lifelong,tcu,edu , ['NonArts']
# http,www,bdshost,com , ['NonArts']
# www,bdshost,com,amrnc , ['NonArts']
# bdshost,com,amrnc,rescmisc , ['NonArts']
# com,amrnc,rescmisc,htm , ['NonArts']
# http,delta,intkey,com , ['NonArts']
# delta,intkey,com,angio , ['NonArts']
# intkey,com,angio,www , ['NonArts']
# com,angio,www,euptelea , ['NonArts']
# angio,www,euptelea,htm , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,petsburgh , ['NonArts']
# geocities,com,petsburgh,fair , ['NonArts']
# http,www,clarehall,cam , ['NonArts']
# www,clarehall,cam,ac , ['NonArts']
# clarehall,cam,ac,uk , ['NonArts']
# cam,ac,uk,index , ['NonArts']
# ac,uk,index,php , ['NonArts']
# uk,index,php,id , ['NonArts']
# http,www,alaha,org , ['Arts']
# http,www,contemplator,com , ['Arts']
# www,contemplator,com,carolan , ['Arts']
# http,www,rocketsciencemovie,com , ['NonArts']
# http,www,compuquilt,com , ['NonArts']
# http,thefrozenfan,wordpress,com , ['NonArts']
# http,www,susannord,com , ['NonArts']
# http,www,philamuseum,org , ['NonArts']
# http,www,safehavengardens,com , ['NonArts']
# www,safehavengardens,com,gsds , ['NonArts']
# safehavengardens,com,gsds,html , ['NonArts']
# http,www,liferites,org , ['NonArts']
# http,www,parks,sa , ['NonArts']
# www,parks,sa,com , ['NonArts']
# parks,sa,com,au , ['NonArts']
# http,www,ldagmachinery,com , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,sunsetstrip , ['NonArts']
# geocities,com,sunsetstrip,mezzanine , ['NonArts']
# http,members,tripod,com , ['NonArts']
# members,tripod,com,lkj , ['NonArts']
# tripod,com,lkj,recipes , ['NonArts']
# com,lkj,recipes,html , ['NonArts']
# http,www,nexx,com , ['NonArts']
# http,www,nlsde,buaa , ['Arts']
# www,nlsde,buaa,edu , ['Arts']
# nlsde,buaa,edu,cn , ['Arts']
# buaa,edu,cn,kexu , ['Arts']
# http,www,haro,online , ['NonArts']
# www,haro,online,com , ['NonArts']
# haro,online,com,movies , ['NonArts']
# online,com,movies,triumph , ['NonArts']
# com,movies,triumph,of , ['NonArts']
# movies,triumph,of,l , ['NonArts']
# http,bobwoodshed,org,beer , ['NonArts']
# http,www,fix,pc , ['NonArts']
# www,fix,pc,com , ['NonArts']
# http,www,kincaidvocational,com , ['NonArts']
# http,www,golfnosis,com , ['NonArts']
# http,www,lauffenmuehle,de , ['Arts']
# http,www,chibipa,com , ['NonArts']
# http,ip,eti,uva , ['NonArts']
# ip,eti,uva,nl , ['NonArts']
# eti,uva,nl,bis , ['NonArts']
# uva,nl,bis,flora , ['NonArts']
# nl,bis,flora,php , ['NonArts']
# bis,flora,php,selected , ['NonArts']
# http,www,bridtownafc,freeserve , ['NonArts']
# www,bridtownafc,freeserve,co , ['NonArts']
# bridtownafc,freeserve,co,uk , ['NonArts']
# http,www,presmont,org , ['NonArts']
# http,www,softuff,org , ['Arts']
# http,www,twomorrows,com , ['NonArts']
# www,twomorrows,com,alterego , ['NonArts']
# twomorrows,com,alterego,articles , ['NonArts']
# http,www,csysa,org , ['NonArts']
# http,www,unlimitedexposure,com , ['Arts']
# http,www,usc,edu , ['NonArts']
# www,usc,edu,dept , ['NonArts']
# usc,edu,dept,polish , ['NonArts']
# edu,dept,polish,music , ['NonArts']
# dept,polish,music,pmj , ['NonArts']
# polish,music,pmj,issue , ['NonArts']
# http,www,lexique,jo , ['NonArts']
# www,lexique,jo,org , ['NonArts']
# http,www,oregonsoapworks,com , ['NonArts']
# http,www,cricketnorthshore,com , ['NonArts']
# http,izfree,sourceforge,net , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,our , ['NonArts']
# geocities,com,our,angel , ['NonArts']
# com,our,angel,kalen , ['NonArts']
# our,angel,kalen,index , ['NonArts']
# http,www,celduc,relais , ['NonArts']
# www,celduc,relais,com , ['NonArts']
# http,www,orgsites,com , ['Arts']
# www,orgsites,com,tx , ['Arts']
# orgsites,com,tx,lscc , ['Arts']
# http,www,metacritic,com , ['NonArts']
# www,metacritic,com,film , ['NonArts']
# metacritic,com,film,titles , ['NonArts']
# com,film,titles,lostandd , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,bullardvb , ['NonArts']
# http,www,jul,com , ['NonArts']
# http,www,shanti,org , ['NonArts']
# http,www,flyfishingnc,com , ['NonArts']
# http,www,qantara,de , ['NonArts']
# www,qantara,de,webcom , ['NonArts']
# qantara,de,webcom,show , ['NonArts']
# de,webcom,show,article , ['NonArts']
# webcom,show,article,php , ['NonArts']
# http,www,storth,com , ['NonArts']
# www,storth,com,pubs , ['NonArts']
# storth,com,pubs,htm , ['NonArts']
# http,www,pbymilwaukee,org , ['NonArts']
# http,www,avea,co , ['Arts']
# www,avea,co,uk , ['Arts']
# http,www,multimedia,search , ['NonArts']
# www,multimedia,search,com , ['NonArts']
# http,money,cnn,com , ['Arts']
# money,cnn,com,news , ['Arts']
# cnn,com,news,newsmaker , ['Arts']
# http,www,onthemedia,org , ['NonArts']
# http,www,resna,org , ['NonArts']
# http,www,everypoet,com , ['NonArts']
# www,everypoet,com,exchange , ['NonArts']
# everypoet,com,exchange,promotion , ['NonArts']
# com,exchange,promotion,htm , ['NonArts']
# http,www,mdexonline,com , ['Arts']
# http,www,angelfire,com , ['NonArts']
# www,angelfire,com,amiga , ['NonArts']
# angelfire,com,amiga,iecwc , ['NonArts']
# http,www,jroy,net , ['NonArts']
# www,jroy,net,castle , ['NonArts']
# jroy,net,castle,fantasy , ['NonArts']
# http,www,idaho,uk , ['NonArts']
# www,idaho,uk,net , ['NonArts']
# http,www,buttons,com , ['NonArts']
# http,www,stillman,edu , ['NonArts']
# http,www,overweightteen,com , ['NonArts']
# http,www,hotinplaystocks,com , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,moctezumaiam , ['NonArts']
# geocities,com,moctezumaiam,eu , ['NonArts']
# com,moctezumaiam,eu,html , ['NonArts']
# http,sportsillustrated,cnn,com , ['NonArts']
# sportsillustrated,cnn,com,cycling , ['NonArts']
# http,www,good,org , ['NonArts']
# http,www,gamefaqs,com , ['NonArts']
# www,gamefaqs,com,console , ['NonArts']
# gamefaqs,com,console,xbox , ['NonArts']
# com,console,xbox,data , ['NonArts']
# http,www,genbukan,biz , ['Arts']
# http,www,buildingrainbows,com , ['NonArts']
# http,www,amandacharles,com , ['NonArts']
# http,www,godsimmediatecontact,com , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,pkniiyama , ['NonArts']
# geocities,com,pkniiyama,evander , ['NonArts']
# com,pkniiyama,evander,ind , ['NonArts']
# http,sports,excite,com , ['NonArts']
# sports,excite,com,wcbk , ['NonArts']
# excite,com,wcbk,teams , ['NonArts']
# com,wcbk,teams,index , ['NonArts']
# wcbk,teams,index,html , ['NonArts']
# http,sporttalk,guardian,co , ['NonArts']
# sporttalk,guardian,co,uk , ['NonArts']
# http,www,ppws,vt , ['NonArts']
# www,ppws,vt,edu , ['NonArts']
# ppws,vt,edu,scott , ['NonArts']
# vt,edu,scott,weed , ['NonArts']
# edu,scott,weed,id , ['NonArts']
# scott,weed,id,dedto , ['NonArts']
# weed,id,dedto,htm , ['NonArts']
# http,www,fitnessexplosion,com , ['NonArts']
# http,ejournals,wspc,com , ['NonArts']
# ejournals,wspc,com,sg , ['NonArts']
# wspc,com,sg,jee , ['NonArts']
# com,sg,jee,s , ['NonArts']
# http,www,whiteparty,org , ['NonArts']
# http,www,peopleoverprofits,org , ['NonArts']
# http,www,gainerweb,com , ['NonArts']
# http,vlado,fmf,uni , ['NonArts']
# vlado,fmf,uni,lj , ['NonArts']
# fmf,uni,lj,si , ['NonArts']
# uni,lj,si,pub , ['NonArts']
# lj,si,pub,networks , ['NonArts']
# si,pub,networks,pajek , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,rnluvs , ['NonArts']
# geocities,com,rnluvs,fly , ['NonArts']
# com,rnluvs,fly,medical , ['NonArts']
# rnluvs,fly,medical,ai , ['NonArts']
# http,www,balzerpacific,com , ['NonArts']
# http,www,muzeji,radovljica , ['NonArts']
# www,muzeji,radovljica,si , ['NonArts']
# http,www,txtlart,com , ['NonArts']
# http,www,uncgspartans,com , ['NonArts']
# www,uncgspartans,com,sportselect , ['NonArts']
# uncgspartans,com,sportselect,dbml , ['NonArts']
# com,sportselect,dbml,d , ['NonArts']
# http,www,online,literature , ['Arts']
# www,online,literature,com , ['Arts']
# online,literature,com,andrew , ['Arts']
# literature,com,andrew,lang , ['Arts']
# com,andrew,lang,r , ['Arts']
# http,www,mmw,com , ['Arts']
# http,www,detroitconcertchoir,org , ['NonArts']
# http,www,taeguspouses,org , ['Arts']
# http,www,freewebs,com , ['NonArts']
# www,freewebs,com,kennychesneyfanactic , ['NonArts']
# http,www,pictureshare,net , ['Arts']
# http,www,classical,net , ['Arts']
# www,classical,net,music , ['Arts']
# classical,net,music,recs , ['Arts']
# net,music,recs,reviews , ['Arts']
# music,recs,reviews,m , ['Arts']
# http,www,premier,net , ['NonArts']
# www,premier,net,cspedale , ['NonArts']
# premier,net,cspedale,opus , ['NonArts']
# net,cspedale,opus,index , ['NonArts']
# cspedale,opus,index,html , ['NonArts']
# http,www,whiterobin,kennels , ['NonArts']
# www,whiterobin,kennels,com , ['NonArts']
# http,www,flexsite,com , ['NonArts']
# http,wc,rootsweb,ancestry , ['NonArts']
# wc,rootsweb,ancestry,com , ['NonArts']
# rootsweb,ancestry,com,cgi , ['NonArts']
# ancestry,com,cgi,bin , ['NonArts']
# com,cgi,bin,igm , ['NonArts']
# cgi,bin,igm,cg , ['NonArts']
# http,www,ospre,co , ['NonArts']
# www,ospre,co,uk , ['NonArts']
# http,www,thedenaligroup,com , ['NonArts']
# http,manomet,org,whsrn , ['NonArts']
# http,www,ahapunanaleo,org , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,cameraghost , ['NonArts']
# http,www,merrybellies,com , ['NonArts']
# http,www,ilovebodykits,com , ['NonArts']
# http,www,teletimecard,com , ['NonArts']
# http,www,journeymenquartet,com , ['Arts']
# http,www,americanhistoricaltheatre,org , ['NonArts']
# http,www,quinnevans,com , ['Arts']
# http,www,users,globalnet , ['Arts']
# www,users,globalnet,co , ['Arts']
# users,globalnet,co,uk , ['Arts']
# globalnet,co,uk,jasen , ['Arts']
# co,uk,jasen,wars , ['Arts']
# http,www,ccupc,org , ['NonArts']
# http,www,gregdavenport,com , ['NonArts']
# http,www,newadvent,org , ['NonArts']
# www,newadvent,org,cathen , ['NonArts']
# newadvent,org,cathen,b , ['NonArts']
# org,cathen,b,htm , ['NonArts']
# http,www,alldj,com , ['NonArts']
# http,www,lib,utexas , ['Arts']
# www,lib,utexas,edu , ['Arts']
# lib,utexas,edu,maps , ['Arts']
# utexas,edu,maps,europe , ['Arts']
# edu,maps,europe,fm , ['Arts']
# maps,europe,fm,yugos , ['Arts']
# http,www,diabeticstoday,com , ['NonArts']
# http,www,mthigh,com , ['NonArts']
# http,www,accutron,com , ['NonArts']
# http,www,hereatcalvary,org , ['NonArts']
# http,aria,maisonx,com , ['NonArts']
# http,www,geocities,com , ['Arts']
# www,geocities,com,river , ['Arts']
# geocities,com,river,tank , ['Arts']
# http,www,religion,online , ['NonArts']
# www,religion,online,org , ['NonArts']
# religion,online,org,showarticle , ['NonArts']
# online,org,showarticle,asp , ['NonArts']
# http,www,klausmeyer,co , ['NonArts']
# www,klausmeyer,co,uk , ['NonArts']
# klausmeyer,co,uk,photos , ['NonArts']
# co,uk,photos,campus , ['NonArts']
# uk,photos,campus,htm , ['NonArts']
# http,members,tripod,com , ['Arts']
# members,tripod,com,zigzag , ['Arts']
# tripod,com,zigzag,index , ['Arts']
# com,zigzag,index,html , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,sunsetstrip , ['NonArts']
# geocities,com,sunsetstrip,villa , ['NonArts']
# http,www,mastermason,com , ['Arts']
# www,mastermason,com,camonlodge , ['Arts']
# http,www,americanidolwatch,com , ['NonArts']
# http,www,st,hamilton , ['NonArts']
# www,st,hamilton,girls , ['NonArts']
# st,hamilton,girls,brigade , ['NonArts']
# hamilton,girls,brigade,org , ['NonArts']
# girls,brigade,org,uk , ['NonArts']
# http,www,lostcatsbrighton,org , ['Arts']
# www,lostcatsbrighton,org,uk , ['Arts']
# http,neelabhagwat,tripod,com , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,siliconvalley , ['NonArts']
# geocities,com,siliconvalley,hills , ['NonArts']
# http,www,pedalcar,com , ['NonArts']
# http,www,qualityonehvac,com , ['Arts']
# http,www,spicygreeniguana,com , ['NonArts']
# http,www,hamillroad,com , ['NonArts']
# http,www,freevault,com , ['NonArts']
# http,www,wkmn,com , ['NonArts']
# http,www,penny,stock , ['NonArts']
# www,penny,stock,picks , ['NonArts']
# penny,stock,picks,com , ['NonArts']
# http,www,imageskill,com , ['Arts']
# www,imageskill,com,tilebuilder , ['Arts']
# imageskill,com,tilebuilder,tilebuil , ['Arts']
# http,www,online,literature , ['NonArts']
# www,online,literature,com , ['NonArts']
# online,literature,com,hawthorne , ['NonArts']
# literature,com,hawthorne,sev , ['NonArts']
# http,www,wired,com , ['NonArts']
# www,wired,com,politics , ['NonArts']
# wired,com,politics,law , ['NonArts']
# com,politics,law,news , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,grm , ['NonArts']
# geocities,com,grm,locost , ['NonArts']
# com,grm,locost,indexx , ['NonArts']
# grm,locost,indexx,html , ['NonArts']
# http,www,robertsrules,com , ['NonArts']
# http,tools,ietf,org , ['NonArts']
# tools,ietf,org,html , ['NonArts']
# ietf,org,html,rfc , ['NonArts']
# http,www,ripleysadventures,com , ['NonArts']
# http,www,grgich,com , ['NonArts']
# http,www,yipesoftware,com , ['NonArts']
# http,www,jjreinke,com , ['Arts']
# http,www,warszawianka,uw , ['Arts']
# www,warszawianka,uw,edu , ['Arts']
# warszawianka,uw,edu,pl , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,kavitayan , ['NonArts']
# geocities,com,kavitayan,portal , ['NonArts']
# com,kavitayan,portal,html , ['NonArts']
# http,www,bravoyankee,es , ['NonArts']
# www,bravoyankee,es,tl , ['NonArts']
# http,www,amio,com , ['NonArts']
# http,www,hibiscus,org , ['Arts']
# http,www,flickfilosopher,com , ['Arts']
# www,flickfilosopher,com,oscars , ['Arts']
# flickfilosopher,com,oscars,bestpix , ['Arts']
# http,www,asciisandbox,bravehost , ['Arts']
# www,asciisandbox,bravehost,com , ['Arts']
# http,www,hollywood,com , ['Arts']
# www,hollywood,com,movies , ['Arts']
# hollywood,com,movies,detail , ['Arts']
# com,movies,detail,id , ['Arts']
# http,www,eastcoastjazz,org , ['NonArts']
# http,www,acmeicon,com , ['NonArts']
# http,www,riordanhs,org , ['NonArts']
# http,www,unicode,org , ['NonArts']
# www,unicode,org,versions , ['NonArts']
# unicode,org,versions,unicode , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,snottywong , ['NonArts']
# geocities,com,snottywong,maxms , ['NonArts']
# http,www,rxlist,com , ['NonArts']
# www,rxlist,com,cgi , ['NonArts']
# rxlist,com,cgi,generic , ['NonArts']
# com,cgi,generic,gemcitab , ['NonArts']
# cgi,generic,gemcitab,htm , ['NonArts']
# http,www,reviewsonline,com , ['NonArts']
# http,www,honeynuttcockers,com , ['NonArts']
# http,www,lgc,golf , ['NonArts']
# www,lgc,golf,co , ['NonArts']
# lgc,golf,co,uk , ['NonArts']
# http,www,vita,bel , ['NonArts']
# www,vita,bel,com , ['NonArts']
# http,hot,black,booty , ['NonArts']
# hot,black,booty,com , ['NonArts']
# black,booty,com,black , ['NonArts']
# booty,com,black,nude , ['NonArts']
# com,black,nude,pics , ['NonArts']
# black,nude,pics,ind , ['NonArts']
# http,www,freewebtown,com , ['NonArts']
# www,freewebtown,com,bensweeting , ['NonArts']
# http,www,lds,org , ['NonArts']
# www,lds,org,placestovisit , ['NonArts']
# lds,org,placestovisit,location , ['NonArts']
# http,www,mesembs,de , ['NonArts']
# http,www,ngtc,com , ['NonArts']
# http,www,hillviewprinting,com , ['NonArts']
# http,www,harrison,co , ['NonArts']
# www,harrison,co,uk , ['NonArts']
# http,www,leaktestingspec,com , ['NonArts']
# http,www,mountainviewsrv,com , ['NonArts']
# http,www,scouter,com , ['NonArts']
# www,scouter,com,compass , ['NonArts']
# http,gotigers,obu,edu , ['Arts']
# gotigers,obu,edu,sport , ['Arts']
# obu,edu,sport,asp , ['Arts']
# edu,sport,asp,sport , ['Arts']
# sport,asp,sport,football , ['Arts']
# http,www,allwatchers,com , ['NonArts']
# www,allwatchers,com,topics , ['NonArts']
# allwatchers,com,topics,info , ['NonArts']
# com,topics,info,asp , ['NonArts']
# http,www,wallaseyrugbyclub,co , ['NonArts']
# www,wallaseyrugbyclub,co,uk , ['NonArts']
# http,www,backontrackpt,com , ['NonArts']
# http,www,geophys,washington , ['NonArts']
# www,geophys,washington,edu , ['NonArts']
# http,skepdic,com,crystals , ['NonArts']
# skepdic,com,crystals,html , ['NonArts']
# http,www,freewebs,com , ['NonArts']
# www,freewebs,com,bannermints , ['NonArts']
# http,www,mech,ubc , ['NonArts']
# www,mech,ubc,ca , ['NonArts']
# mech,ubc,ca,mal , ['NonArts']
# http,www,phdproject,org , ['NonArts']
# http,www,layeronecabling,com , ['NonArts']
# http,www,somersavenue,org , ['NonArts']
# http,www,felineinstincts,com , ['NonArts']
# http,www,sexfromhell,com , ['NonArts']
# www,sexfromhell,com,evilforce , ['NonArts']
# sexfromhell,com,evilforce,index , ['NonArts']
# com,evilforce,index,html , ['NonArts']
# http,lawprofessors,typepad,com , ['NonArts']
# lawprofessors,typepad,com,tortsprof , ['NonArts']
# http,www,wolfeargent,com , ['NonArts']
# http,www,iraniabrasives,com , ['NonArts']
# http,www,holisticpage,com , ['NonArts']
# www,holisticpage,com,au , ['NonArts']
# http,www,healthsystem,virginia , ['NonArts']
# www,healthsystem,virginia,edu , ['NonArts']
# healthsystem,virginia,edu,internet , ['NonArts']
# http,www,lechasseur,com , ['NonArts']
# http,www,physics,curtin , ['NonArts']
# www,physics,curtin,edu , ['NonArts']
# physics,curtin,edu,au , ['NonArts']
# http,www,breconshiredarts,co , ['NonArts']
# www,breconshiredarts,co,uk , ['NonArts']
# http,www,us,playstation , ['NonArts']
# www,us,playstation,com , ['NonArts']
# us,playstation,com,parappatherapper , ['NonArts']
# http,fernet,tripod,com , ['Arts']
# fernet,tripod,com,fashion , ['Arts']
# tripod,com,fashion,html , ['Arts']
# http,www,metacritic,com , ['Arts']
# www,metacritic,com,film , ['Arts']
# metacritic,com,film,titles , ['Arts']
# com,film,titles,intimacy , ['Arts']
# http,hansonstar,tripod,com , ['NonArts']
# http,www,watford,nazarene , ['Arts']
# www,watford,nazarene,org , ['Arts']
# watford,nazarene,org,uk , ['Arts']
# http,en,wikipedia,org , ['NonArts']
# en,wikipedia,org,wiki , ['NonArts']
# wikipedia,org,wiki,orazio , ['NonArts']
# org,wiki,orazio,gentileschi , ['NonArts']
# http,www,cncherry,com , ['NonArts']
# http,www,thetubecenter,com , ['NonArts']
# http,starship,python,net , ['NonArts']
# starship,python,net,crew , ['NonArts']
# python,net,crew,manus , ['NonArts']
# net,crew,manus,presiden , ['NonArts']
# http,www,tcil,com , ['NonArts']
# http,www,girlguides,ca , ['NonArts']
# http,home,earthlink,net , ['Arts']
# home,earthlink,net,miracleoflife , ['Arts']
# http,www,vintage,gibson , ['NonArts']
# www,vintage,gibson,les , ['NonArts']
# vintage,gibson,les,pauls , ['NonArts']
# gibson,les,pauls,ukartists , ['NonArts']
# http,www,gamespot,com , ['Arts']
# www,gamespot,com,xbox , ['Arts']
# gamespot,com,xbox,action , ['Arts']
# com,xbox,action,maxpayne , ['Arts']
# http,apolloguide,com,mov , ['NonArts']
# apolloguide,com,mov,revtemp , ['NonArts']
# com,mov,revtemp,asp , ['NonArts']
# mov,revtemp,asp,cid , ['NonArts']
# http,www,parrotpages,com , ['NonArts']
# www,parrotpages,com,cncaviary , ['NonArts']
# http,www,amateur,teen , ['NonArts']
# www,amateur,teen,lesbian , ['NonArts']
# amateur,teen,lesbian,sex , ['NonArts']
# teen,lesbian,sex,com , ['NonArts']
# lesbian,sex,com,adult , ['NonArts']
# http,www,rpg,net , ['NonArts']
# www,rpg,net,reviews , ['NonArts']
# rpg,net,reviews,archive , ['NonArts']
# net,reviews,archive,phtml , ['NonArts']
# http,www,signspecialist,com , ['NonArts']
# http,www,broadband,help , ['NonArts']
# www,broadband,help,com , ['NonArts']
# broadband,help,com,tools , ['NonArts']
# help,com,tools,speed , ['NonArts']
# com,tools,speed,test , ['NonArts']
# http,www,nelaser,com , ['NonArts']
# http,www,comerinc,com , ['NonArts']
# http,www,construction,software , ['NonArts']
# www,construction,software,com , ['NonArts']
# http,www,design,av , ['NonArts']
# www,design,av,com , ['NonArts']
# http,www,botany,hawaii , ['NonArts']
# www,botany,hawaii,edu , ['NonArts']
# botany,hawaii,edu,faculty , ['NonArts']
# hawaii,edu,faculty,carr , ['NonArts']
# edu,faculty,carr,imag , ['NonArts']
# http,cyveillance,linuxgod,net , ['NonArts']
# http,www,newadvent,org , ['NonArts']
# www,newadvent,org,cathen , ['NonArts']
# newadvent,org,cathen,c , ['NonArts']
# org,cathen,c,htm , ['NonArts']
# http,www,slaffart,com , ['NonArts']
# http,www,schmitt,maschinen , ['NonArts']
# www,schmitt,maschinen,de , ['NonArts']
# http,www,botany,hawaii , ['NonArts']
# www,botany,hawaii,edu , ['NonArts']
# botany,hawaii,edu,faculty , ['NonArts']
# hawaii,edu,faculty,carr , ['NonArts']
# edu,faculty,carr,imag , ['NonArts']
# http,www,lakesmach,com , ['NonArts']
# http,www,phase,quest , ['NonArts']
# www,phase,quest,com , ['NonArts']
# http,www,burchmfg,net , ['NonArts']
# http,www,jimforeman,com , ['NonArts']
# http,www,nlassn,org , ['NonArts']
# http,www,regionalwines,co , ['NonArts']
# www,regionalwines,co,nz , ['NonArts']
# http,www,vomillerdamm,com , ['NonArts']
# http,www,awmi,net , ['Arts']
# http,www,rwhirled,com , ['NonArts']
# www,rwhirled,com,mads , ['NonArts']
# rwhirled,com,mads,met , ['NonArts']
# com,mads,met,htm , ['NonArts']
# http,www,ibiblio,org , ['NonArts']
# www,ibiblio,org,pfaf , ['NonArts']
# ibiblio,org,pfaf,cgi , ['NonArts']
# org,pfaf,cgi,bin , ['NonArts']
# pfaf,cgi,bin,arr , ['NonArts']
# cgi,bin,arr,html , ['NonArts']
# bin,arr,html,c , ['NonArts']
# http,www,ptbas,org , ['NonArts']
# http,hamiltonholtinc,stores,yahoo , ['NonArts']
# hamiltonholtinc,stores,yahoo,net , ['NonArts']
# http,www,mastermason,com , ['NonArts']
# www,mastermason,com,louisianadistrict , ['NonArts']
# http,bwhome,intheteam,com , ['NonArts']
# http,naia,cstv,com , ['NonArts']
# naia,cstv,com,sports , ['NonArts']
# cstv,com,sports,w , ['NonArts']
# com,sports,w,otrack , ['NonArts']
# sports,w,otrack,naia , ['NonArts']
# w,otrack,naia,w , ['NonArts']
# otrack,naia,w,ot , ['NonArts']
# http,www,planetpdf,com , ['NonArts']
# www,planetpdf,com,planetpdf , ['NonArts']
# planetpdf,com,planetpdf,pdfs , ['NonArts']
# com,planetpdf,pdfs,comput , ['NonArts']
# http,www,majon,com , ['NonArts']
# http,www,goskyhawks,com , ['Arts']
# www,goskyhawks,com,index , ['Arts']
# goskyhawks,com,index,asp , ['Arts']
# com,index,asp,path , ['Arts']
# index,asp,path,wbball , ['Arts']
# http,www,sympatico,ca , ['Arts']
# www,sympatico,ca,alan , ['Arts']
# sympatico,ca,alan,teder , ['Arts']
# ca,alan,teder,vtinfoarch , ['Arts']
# http,www,ujicha,com , ['NonArts']
# www,ujicha,com,e , ['NonArts']
# ujicha,com,e,index , ['NonArts']
# com,e,index,html , ['NonArts']
# http,www,faqs,org , ['NonArts']
# www,faqs,org,faqs , ['NonArts']
# faqs,org,faqs,dogs , ['NonArts']
# org,faqs,dogs,faq , ['NonArts']
# faqs,dogs,faq,breeds , ['NonArts']
# dogs,faq,breeds,bosto , ['NonArts']
# http,www,timen,com , ['NonArts']
# www,timen,com,blog , ['NonArts']
# http,www,pcmag,com , ['NonArts']
# www,pcmag,com,category , ['NonArts']
# pcmag,com,category,asp , ['NonArts']
# http,www,gocolumbialions,com , ['NonArts']
# www,gocolumbialions,com,sportselect , ['NonArts']
# gocolumbialions,com,sportselect,dbm , ['NonArts']
# http,ndpr,nd,edu , ['Arts']
# ndpr,nd,edu,review , ['Arts']
# nd,edu,review,cfm , ['Arts']
# edu,review,cfm,id , ['Arts']
# http,www,angelfire,com , ['NonArts']
# www,angelfire,com,art , ['NonArts']
# angelfire,com,art,thaumaturgy , ['NonArts']
# http,sric,canada,org , ['NonArts']
# sric,canada,org,mcleodmoorecollege , ['NonArts']
# canada,org,mcleodmoorecollege,html , ['NonArts']
# http,www,planemath,com , ['NonArts']
# http,www,ibcrootbeer,com , ['NonArts']
# http,www,blizzard,com , ['NonArts']
# www,blizzard,com,war , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,cupid , ['NonArts']
# geocities,com,cupid,the , ['NonArts']
# com,cupid,the,scorpion , ['NonArts']
# http,www,med,mun , ['NonArts']
# www,med,mun,ca , ['NonArts']
# med,mun,ca,munmed , ['NonArts']
# mun,ca,munmed,vietnam , ['NonArts']
# ca,munmed,vietnam,htm , ['NonArts']
# http,www,factmonster,com , ['NonArts']
# www,factmonster,com,ce , ['NonArts']
# factmonster,com,ce,people , ['NonArts']
# com,ce,people,a , ['NonArts']
# http,www,webnetc,com , ['NonArts']
# www,webnetc,com,au , ['NonArts']
# http,www,aztriad,com , ['NonArts']
# www,aztriad,com,whatall , ['NonArts']
# aztriad,com,whatall,html , ['NonArts']
# http,www,yankeeharvest,com , ['NonArts']
# www,yankeeharvest,com,pumpkin , ['NonArts']
# yankeeharvest,com,pumpkin,index , ['NonArts']
# com,pumpkin,index,html , ['NonArts']
# http,www,the,online , ['Arts']
# www,the,online,casinos , ['Arts']
# the,online,casinos,com , ['Arts']
# http,www,latingate,com , ['NonArts']
# http,www,organiccottonplus,com , ['NonArts']
# http,www,msu,edu , ['NonArts']
# www,msu,edu,unit , ['NonArts']
# msu,edu,unit,ophs , ['NonArts']
# http,allrecipes,com,recipe , ['NonArts']
# allrecipes,com,recipe,smoky , ['NonArts']
# com,recipe,smoky,cod , ['NonArts']
# recipe,smoky,cod,and , ['NonArts']
# smoky,cod,and,par , ['NonArts']
# http,www,articlesnare,com , ['NonArts']
# http,avalon,law,yale , ['NonArts']
# avalon,law,yale,edu , ['NonArts']
# law,yale,edu,imt , ['NonArts']
# yale,edu,imt,judseyss , ['NonArts']
# edu,imt,judseyss,asp , ['NonArts']
# http,www,socwildcatstrackclub,com , ['NonArts']
# http,www,serendipity,li , ['NonArts']
# www,serendipity,li,wtc , ['NonArts']
# serendipity,li,wtc,htm , ['NonArts']
# http,www,uiuc,edu , ['Arts']
# www,uiuc,edu,ro , ['Arts']
# uiuc,edu,ro,pbp , ['Arts']
# http,www,mts,net , ['Arts']
# www,mts,net,william , ['Arts']
# mts,net,william,sld , ['Arts']
# net,william,sld,htm , ['Arts']
# http,groups,yahoo,com , ['NonArts']
# groups,yahoo,com,group , ['NonArts']
# yahoo,com,group,eltonjohn , ['NonArts']
# http,www,happydaycards,com , ['NonArts']
# www,happydaycards,com,stories , ['NonArts']
# happydaycards,com,stories,easterfab , ['NonArts']
# http,www,ezinearticles,biz , ['NonArts']
# http,www,services,com , ['NonArts']
# http,www,biodaqua,org , ['NonArts']
# http,www,bridgecreek,ca , ['NonArts']
# http,www,holmesatty,com , ['NonArts']
# http,www,sayitinstone,com , ['NonArts']
# http,jeremy,zawodny,com , ['NonArts']
# jeremy,zawodny,com,blog , ['NonArts']
# http,www,exoticimports,com , ['NonArts']
# http,florawww,eeb,uconn , ['NonArts']
# florawww,eeb,uconn,edu , ['NonArts']
# eeb,uconn,edu,html , ['NonArts']
# http,ds,ign,com , ['Arts']
# ds,ign,com,objects , ['Arts']
# ign,com,objects,html , ['Arts']
# http,www,theancestors,com , ['NonArts']
# http,www,manitobabearhunts,ca , ['NonArts']
# http,www,drwakefield,com , ['Arts']
# http,www,live,com , ['NonArts']
# www,live,com,stations , ['NonArts']
# http,www,palmsource,com , ['NonArts']
# http,www,onetouchgt,com , ['NonArts']
# http,coastman,free,fr , ['NonArts']
# http,www,alpinevalleyresort,com , ['NonArts']
# http,www,mosaicworkshop,com , ['NonArts']
# http,pds,jpl,nasa , ['NonArts']
# pds,jpl,nasa,gov , ['NonArts']
# http,www,transilvaniaproduction,ro , ['NonArts']
# http,www,malcolmadams,com , ['NonArts']
# www,malcolmadams,com,itunes , ['NonArts']
# http,www,ampthillmethodist,org , ['NonArts']
# www,ampthillmethodist,org,uk , ['NonArts']
# http,www,studio,denia , ['NonArts']
# www,studio,denia,com , ['NonArts']
# http,www,chami,com , ['NonArts']
# www,chami,com,html , ['NonArts']
# chami,com,html,kit , ['NonArts']
# com,html,kit,devtools , ['NonArts']
# http,darkwing,uoregon,edu , ['NonArts']
# darkwing,uoregon,edu,jdst , ['NonArts']
# http,www,shalomjerusalem,com , ['NonArts']
# www,shalomjerusalem,com,heritage , ['NonArts']
# http,www,awbs,org , ['NonArts']
# www,awbs,org,uk , ['NonArts']
# http,www,sptimes,com , ['Arts']
# www,sptimes,com,news , ['Arts']
# sptimes,com,news,northpinell , ['Arts']
# http,www,ronkaplan,com , ['NonArts']
# http,www,mikegreen,iwarp , ['NonArts']
# www,mikegreen,iwarp,com , ['NonArts']
# http,www,texasferret,org , ['NonArts']
# http,www,softease,com , ['NonArts']
# http,freewebs,com,fig , ['NonArts']
# freewebs,com,fig,forangel , ['NonArts']
# http,www,tumu,com , ['NonArts']
# http,www,dolphins,asc , ['NonArts']
# www,dolphins,asc,fsnet , ['NonArts']
# dolphins,asc,fsnet,co , ['NonArts']
# asc,fsnet,co,uk , ['NonArts']
# http,www,microsoft,com , ['Arts']
# www,microsoft,com,games , ['Arts']
# microsoft,com,games,conquerors , ['Arts']
# http,gloomsday,net,kate , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,area , ['NonArts']
# geocities,com,area,orion , ['NonArts']
# com,area,orion,etr , ['NonArts']
# http,www,torry,net , ['NonArts']
# http,www,ugallery,com , ['Arts']
# http,www,aintitcool,com , ['NonArts']
# www,aintitcool,com,node , ['NonArts']
# http,store,parklane,com , ['NonArts']
# http,www,concordiacardinals,com , ['NonArts']
# www,concordiacardinals,com,sport , ['NonArts']
# concordiacardinals,com,sport,php , ['NonArts']
# http,www,guidemag,com , ['NonArts']
# http,www,angelfire,com , ['NonArts']
# www,angelfire,com,tx , ['NonArts']
# angelfire,com,tx,cleo , ['NonArts']
# com,tx,cleo,alex , ['NonArts']
# http,www,ianrpubs,unl , ['Arts']
# www,ianrpubs,unl,edu , ['Arts']
# ianrpubs,unl,edu,epublic , ['Arts']
# unl,edu,epublic,pages , ['Arts']
# edu,epublic,pages,publ , ['Arts']
# http,www,lisa,org , ['NonArts']
# www,lisa,org,au , ['NonArts']
# http,www,freewebs,com , ['NonArts']
# www,freewebs,com,sonnexpetssecrets , ['NonArts']
# http,www,john,shuttleworth , ['NonArts']
# www,john,shuttleworth,com , ['NonArts']
# http,emmdeb,mysite,maltanet , ['NonArts']
# emmdeb,mysite,maltanet,net , ['NonArts']
# http,www,grovegear,com , ['NonArts']
# http,en,wikipedia,org , ['Arts']
# en,wikipedia,org,wiki , ['Arts']
# wikipedia,org,wiki,mortal , ['Arts']
# org,wiki,mortal,kombat , ['Arts']
# wiki,mortal,kombat,series , ['Arts']
# http,www,sensesofcinema,com , ['NonArts']
# www,sensesofcinema,com,contents , ['NonArts']
# sensesofcinema,com,contents,gr , ['NonArts']
# http,www,gamespot,com , ['NonArts']
# www,gamespot,com,wii , ['NonArts']
# gamespot,com,wii,puzzle , ['NonArts']
# com,wii,puzzle,groovinblocks , ['NonArts']
# http,www,informedchoices,org , ['NonArts']
# http,www,gbgm,umc , ['Arts']
# www,gbgm,umc,org , ['Arts']
# gbgm,umc,org,doubs , ['Arts']
# umc,org,doubs,epworth , ['Arts']
# http,www,tvguide,com , ['NonArts']
# www,tvguide,com,movies , ['NonArts']
# tvguide,com,movies,limits , ['NonArts']
# http,www,shinegallery,com , ['NonArts']
# http,iridia,ulb,ac , ['NonArts']
# iridia,ulb,ac,be , ['NonArts']
# ulb,ac,be,projects , ['NonArts']
# ac,be,projects,phras , ['NonArts']
# be,projects,phras,html , ['NonArts']
# http,www,donahue,inc , ['NonArts']
# www,donahue,inc,com , ['NonArts']
# http,www,chirunning,com , ['NonArts']
# http,freemasonry,nf,ca , ['NonArts']
# freemasonry,nf,ca,l , ['NonArts']
# nf,ca,l,html , ['NonArts']
# http,www,interscience,wiley , ['NonArts']
# www,interscience,wiley,com , ['NonArts']
# interscience,wiley,com,journal , ['NonArts']
# http,www,spiritual,exercises , ['NonArts']
# www,spiritual,exercises,com , ['NonArts']
# http,www,ragoshapewear,com , ['NonArts']
# http,www,birkettcontrols,com , ['NonArts']
# www,birkettcontrols,com,au , ['NonArts']
# http,www,libertonrugby,co , ['NonArts']
# www,libertonrugby,co,uk , ['NonArts']
# http,www,irs,siu , ['Arts']
# www,irs,siu,edu , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,csusbdc , ['NonArts']
# http,officewriter,softartisans,com , ['NonArts']
# http,www,ronaldo,com , ['NonArts']
# http,www,foodphotolibrary,com , ['NonArts']
# http,www,miniaturereef,com , ['NonArts']
# http,www,cura,net , ['NonArts']
# www,cura,net,rosario , ['NonArts']
# http,www,clockdials,com , ['NonArts']
# http,tools,ietf,org , ['Arts']
# tools,ietf,org,html , ['Arts']
# ietf,org,html,rfc , ['Arts']
# http,www,dukesofdestiny,com , ['NonArts']
# http,www,physicsmyths,org , ['NonArts']
# www,physicsmyths,org,uk , ['NonArts']
# http,www,zen,deshimaru , ['NonArts']
# www,zen,deshimaru,nl , ['NonArts']
# http,www,handfamily,org , ['NonArts']
# http,www,memorgan,com , ['NonArts']
# http,www,hemophilia,org , ['Arts']
# http,www,sfcrowsnest,com , ['NonArts']
# www,sfcrowsnest,com,sfnews , ['NonArts']
# sfcrowsnest,com,sfnews,oct , ['NonArts']
# com,sfnews,oct,revi , ['NonArts']
# http,www,dana,edu , ['NonArts']
# http,www,ashememorial,org , ['NonArts']
# http,www,sjsu,edu , ['NonArts']
# www,sjsu,edu,faculty , ['NonArts']
# sjsu,edu,faculty,watkins , ['NonArts']
# edu,faculty,watkins,r , ['NonArts']
# faculty,watkins,r,htm , ['NonArts']
# http,www,soccerbase,com , ['NonArts']
# www,soccerbase,com,teams , ['NonArts']
# soccerbase,com,teams,sd , ['NonArts']
# com,teams,sd,teamid , ['NonArts']
# http,www,swirlednews,com , ['NonArts']
# http,case,tm,lawschool , ['Arts']
# case,tm,lawschool,lawschool , ['Arts']
# tm,lawschool,lawschool,html , ['Arts']
# http,www,vh,com , ['NonArts']
# www,vh,com,artists , ['NonArts']
# vh,com,artists,az , ['NonArts']
# com,artists,az,id , ['NonArts']
# artists,az,id,artist , ['NonArts']
# az,id,artist,j , ['NonArts']
# http,bensguide,gpo,gov , ['NonArts']
# bensguide,gpo,gov,election , ['NonArts']
# gpo,gov,election,index , ['NonArts']
# gov,election,index,html , ['NonArts']
# http,www,allenlopez,com , ['NonArts']
# http,www,orgyn,com , ['NonArts']
# www,orgyn,com,en , ['NonArts']
# orgyn,com,en,webzine , ['NonArts']
# com,en,webzine,issue , ['NonArts']
# http,sportsillustrated,cnn,com , ['NonArts']
# sportsillustrated,cnn,com,soccer , ['NonArts']
# cnn,com,soccer,p , ['NonArts']
# http,www,smt,gb , ['NonArts']
# www,smt,gb,com , ['NonArts']
# http,www,beeinvited,net , ['NonArts']
# http,www,rdc,ab , ['NonArts']
# www,rdc,ab,ca , ['NonArts']
# rdc,ab,ca,athletics , ['NonArts']
# ab,ca,athletics,kings , ['NonArts']
# ca,athletics,kings,basketbal , ['NonArts']
# http,www,arc,duxford , ['NonArts']
# www,arc,duxford,co , ['NonArts']
# arc,duxford,co,uk , ['NonArts']
# http,www,unitarian,org , ['NonArts']
# www,unitarian,org,uk , ['NonArts']
# unitarian,org,uk,emu , ['NonArts']
# org,uk,emu,lincoln , ['NonArts']
# http,www,entrac,petroleum , ['NonArts']
# www,entrac,petroleum,com , ['NonArts']
# http,www,kennethwyatt,com , ['NonArts']
# http,health,groups,yahoo , ['Arts']
# health,groups,yahoo,com , ['Arts']
# groups,yahoo,com,group , ['Arts']
# yahoo,com,group,healinghs , ['Arts']
# http,perso,wanadoo,es , ['NonArts']
# perso,wanadoo,es,fsalvaje , ['NonArts']
# http,www,sauconvalleycc,org , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,universalmonsters , ['NonArts']
# http,www,chelonia,demon , ['NonArts']
# www,chelonia,demon,co , ['NonArts']
# chelonia,demon,co,uk , ['NonArts']
# http,www,design,com , ['NonArts']
# http,chuck,baker,tripod , ['NonArts']
# chuck,baker,tripod,com , ['NonArts']
# http,www,gridbus,org , ['NonArts']
# www,gridbus,org,grid , ['NonArts']
# http,athletics,bethany,edu , ['NonArts']
# athletics,bethany,edu,index , ['NonArts']
# bethany,edu,index,asp , ['NonArts']
# edu,index,asp,path , ['NonArts']
# index,asp,path,ws , ['NonArts']
# http,www,rothsaybiodiesel,ca , ['Arts']
# http,www,askmen,com , ['Arts']
# www,askmen,com,women , ['Arts']
# askmen,com,women,singer , ['Arts']
# com,women,singer,diana , ['Arts']
# women,singer,diana,kr , ['Arts']
# http,en,wikipedia,org , ['NonArts']
# en,wikipedia,org,wiki , ['NonArts']
# wikipedia,org,wiki,to , ['NonArts']
# org,wiki,to,yuma , ['NonArts']
# wiki,to,yuma,( , ['NonArts']
# http,www,lincolnorchidsociety,org , ['NonArts']
# http,hem,passagen,se , ['NonArts']
# hem,passagen,se,alheims , ['NonArts']
# http,user,cs,tu , ['NonArts']
# user,cs,tu,berlin , ['NonArts']
# cs,tu,berlin,de , ['NonArts']
# tu,berlin,de,sepp , ['NonArts']
# berlin,de,sepp,jacob , ['NonArts']
# de,sepp,jacob,wurz , ['NonArts']
# http,www,americanstyledarts,com , ['NonArts']
# http,channeling,awardspace,com , ['NonArts']
# http,allrecipes,com,recipe , ['Arts']
# allrecipes,com,recipe,birds , ['Arts']
# com,recipe,birds,nest , ['Arts']
# recipe,birds,nest,puddin , ['Arts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,area , ['NonArts']
# geocities,com,area,shadowlands , ['NonArts']
# http,www,schwimmer,com , ['NonArts']
# www,schwimmer,com,fourchaplains , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,molterlauren , ['NonArts']
# http,www,sailingacross,com , ['Arts']
# http,www,juegosdepucca,net , ['NonArts']
# http,www,clinicalresearchjobs,co , ['Arts']
# www,clinicalresearchjobs,co,uk , ['Arts']
# http,www,ayu,mi , ['NonArts']
# www,ayu,mi,x , ['NonArts']
# ayu,mi,x,com , ['NonArts']
# http,www,drforsell,com , ['Arts']
# http,www,firsttvdrama,com , ['NonArts']
# www,firsttvdrama,com,show , ['NonArts']
# firsttvdrama,com,show,largcast , ['NonArts']
# com,show,largcast,tra , ['NonArts']
# http,www,pracweb,com , ['NonArts']
# www,pracweb,com,cd , ['NonArts']
# pracweb,com,cd,html , ['NonArts']
# http,www,premierleague,com , ['Arts']
# http,www,musica,mundi , ['NonArts']
# www,musica,mundi,com , ['NonArts']
# http,www,getty,edu , ['NonArts']
# www,getty,edu,art , ['NonArts']
# getty,edu,art,exhibitions , ['NonArts']
# edu,art,exhibitions,books , ['NonArts']
# http,www,helpingoutpetseveryday,com , ['NonArts']
# http,www,rrmdesign,com , ['NonArts']
# http,www,affiliatetip,com , ['NonArts']
# http,www,emaohio,org , ['Arts']
# http,synthsite,m,com , ['NonArts']
# http,www,bessel,org , ['NonArts']
# www,bessel,org,armihist , ['NonArts']
# bessel,org,armihist,htm , ['NonArts']
# http,creatures,ifas,ufl , ['NonArts']
# creatures,ifas,ufl,edu , ['NonArts']
# ifas,ufl,edu,orn , ['NonArts']
# ufl,edu,orn,trees , ['NonArts']
# edu,orn,trees,pseudo , ['NonArts']
# http,www,doomsdayhq,com , ['NonArts']
# http,www,astro,hr , ['NonArts']
# www,astro,hr,ucionica , ['NonArts']
# http,www,dollfacepunk,com , ['NonArts']
# http,rseg,dvo,ru , ['Arts']
# http,www,jewellegomez,com , ['NonArts']
# http,www,capebethel,org , ['NonArts']
# http,www,yourinvited,com , ['NonArts']
# www,yourinvited,com,au , ['NonArts']
# http,www,scottriggs,com , ['NonArts']
# http,www,eteamz,com , ['NonArts']
# www,eteamz,com,staffordbrasil , ['NonArts']
# http,www,glassclub,org , ['NonArts']
# http,www,corkandross,org , ['Arts']
# http,www,teamenglish,com , ['NonArts']
# www,teamenglish,com,recruit , ['NonArts']
# http,www,maxhilaire,com , ['NonArts']
# http,www,healthyhosiery,com , ['NonArts']
# http,www,greenflooring,com , ['NonArts']
# http,www,ne,techservices , ['NonArts']
# www,ne,techservices,com , ['NonArts']
# http,www,telebyte,com , ['Arts']
# www,telebyte,com,d , ['Arts']
# telebyte,com,d,rainbow , ['Arts']
# http,www,hoasm,org , ['NonArts']
# www,hoasm,org,ivm , ['NonArts']
# hoasm,org,ivm,lanier , ['NonArts']
# org,ivm,lanier,html , ['NonArts']
# http,www,linguatots,com , ['Arts']
# http,www,allclassical,net , ['NonArts']
# www,allclassical,net,music , ['NonArts']
# allclassical,net,music,comp , ['NonArts']
# net,music,comp,lst , ['NonArts']
# music,comp,lst,acc , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,colosseum , ['NonArts']
# geocities,com,colosseum,bench , ['NonArts']
# http,www,southernct,edu , ['NonArts']
# www,southernct,edu,art , ['NonArts']
# http,aplacetogo,homestead,com , ['NonArts']
# aplacetogo,homestead,com,hi , ['NonArts']
# homestead,com,hi,html , ['NonArts']
# http,www,kangmei,com , ['NonArts']
# http,www,glmenthol,com , ['NonArts']
# http,www,holdinggold,com , ['NonArts']
# http,www,churchofthenewaeon,org , ['Arts']
# http,rogerebert,suntimes,com , ['NonArts']
# ...
# http,www,asianfortunenews,com , ['NonArts']
# http,www,muw,edu , ['NonArts']
# www,muw,edu,spectator , ['NonArts']
# http,www,granitefallsnews,com , ['NonArts']
# http,www,mediaweek,com , ['NonArts']
# http,www,yarka,net , ['NonArts']
# http,www,thedailyworld,com , ['NonArts']
# http,www,tcbaker,net , ['NonArts']
# http,www,gadsdentimes,com , ['NonArts']
# http,www,lodinews,com , ['NonArts']
# http,www,nnsl,com , ['NonArts']
# http,www,nnsl,com , ['NonArts']
# www,nnsl,com,dehcho , ['NonArts']
# nnsl,com,dehcho,index , ['NonArts']
# com,dehcho,index,html , ['NonArts']
# http,www,dailysouthtown,com , ['NonArts']
# http,arapaho,nsuok,edu , ['NonArts']
# arapaho,nsuok,edu,tne , ['NonArts']
# http,www,timesleader,net , ['NonArts']
# http,www,examinernews,com , ['NonArts']
# www,examinernews,com,west , ['NonArts']
# examinernews,com,west,university , ['NonArts']
# http,www,inanews,com , ['NonArts']
# http,www,leadernewspapers,net , ['NonArts']
# http,bibelen,blogspot,com , ['NonArts']
# http,www,tfponline,com , ['NonArts']
# http,www,castic,com , ['NonArts']
# http,www,jasperbooster,com , ['NonArts']
# http,www,nlrtimes,com , ['NonArts']
# http,www,guardian,co , ['NonArts']
# www,guardian,co,uk , ['NonArts']
# guardian,co,uk,lifeandstyle , ['NonArts']
# co,uk,lifeandstyle,de , ['NonArts']
# http,mob,ndbc,noaa , ['NonArts']
# mob,ndbc,noaa,gov , ['NonArts']
# ndbc,noaa,gov,cgi , ['NonArts']
# noaa,gov,cgi,bin , ['NonArts']
# gov,cgi,bin,mob , ['NonArts']
# cgi,bin,mob,cgi , ['NonArts']
# http,www,alconareview,com , ['NonArts']
# http,www,ecobserver,com , ['NonArts']
# http,www,lisleuth,com , ['NonArts']
# http,www,frankwbaker,com , ['NonArts']
# http,www,southwestobserver,com , ['NonArts']
# http,www,starobserver,com , ['NonArts']
# www,starobserver,com,au , ['NonArts']
# http,www,reviewmessenger,com , ['NonArts']
# http,www,dobsonagency,co , ['NonArts']
# www,dobsonagency,co,uk , ['NonArts']
# http,www,metronews,com , ['NonArts']
# http,tampabay,bizjournals,com , ['NonArts']
# tampabay,bizjournals,com,tampabay , ['NonArts']
# http,www,fair,org , ['NonArts']
# www,fair,org,index , ['NonArts']
# fair,org,index,php , ['NonArts']
# org,index,php,page , ['NonArts']
# index,php,page,amp;issue , ['NonArts']
# http,hosted,ap,org , ['NonArts']
# hosted,ap,org,lineups , ['NonArts']
# ap,org,lineups,worldheads , ['NonArts']
# org,lineups,worldheads,rss , ['NonArts']
# http,www,bongonews,com , ['NonArts']
# http,www,masslawyersweekly,com , ['NonArts']
# http,www,rsf,org , ['NonArts']
# www,rsf,org,rubrique , ['NonArts']
# rsf,org,rubrique,php , ['NonArts']
# org,rubrique,php,id , ['NonArts']
# rubrique,php,id,rubrique , ['NonArts']
# http,www,bacons,com , ['NonArts']
# http,www,medianewsline,com , ['NonArts']
# http,www,ku,edu , ['NonArts']
# www,ku,edu,acejmc , ['NonArts']
# http,thescope,ca,feed , ['NonArts']
# thescope,ca,feed,rss , ['NonArts']
# http,www,enpa,be , ['NonArts']
# http,www,nowchannel,com , ['NonArts']
# www,nowchannel,com,news , ['NonArts']
# http,www,berkeley,edu , ['NonArts']
# www,berkeley,edu,news , ['NonArts']
# http,www,shns,com , ['NonArts']
# http,www,jaymallinphotos,com , ['NonArts']
# http,www,zwire,com , ['NonArts']
# www,zwire,com,site , ['NonArts']
# zwire,com,site,news , ['NonArts']
# com,site,news,asp , ['NonArts']
# site,news,asp,brd , ['NonArts']
# http,www,simedia,org , ['NonArts']
# http,www,gunnisontimes,com , ['NonArts']
# http,www,facsnet,org , ['NonArts']
# www,facsnet,org,index , ['NonArts']
# facsnet,org,index,php , ['NonArts']
# org,index,php,option , ['NonArts']
# index,php,option,com , ['NonArts']
# php,option,com,co , ['NonArts']
# http,lobby,it,com , ['NonArts']
# http,www,agstar,com , ['NonArts']
# www,agstar,com,ni , ['NonArts']
# http,www,thescribeonline,com , ['NonArts']
# http,www,cychron,com , ['NonArts']
# www,cychron,com,articles , ['NonArts']
# cychron,com,articles,rss , ['NonArts']
# http,www,laketimes,com , ['NonArts']
# www,laketimes,com,au , ['NonArts']
# http,www,theorangecountynews,com , ['NonArts']
# http,www,dolanmedia,com , ['NonArts']
# http,www,naegelen,com , ['NonArts']
# http,www,michiganreview,com , ['NonArts']
# http,www,indianagazette,com , ['NonArts']
# http,news,mywebpal,com , ['NonArts']
# news,mywebpal,com,partners , ['NonArts']
# mywebpal,com,partners,public , ['NonArts']
# com,partners,public,i , ['NonArts']
# http,www,corydondemocrat,com , ['NonArts']
# http,www,quesnelobserver,com , ['NonArts']
# http,www,emorywheel,com , ['NonArts']
# http,www,newsombudsmen,org , ['NonArts']
# http,collie,yourguide,com , ['NonArts']
# collie,yourguide,com,au , ['NonArts']
# http,www,timeswv,com , ['NonArts']
# http,www,phogle,com , ['NonArts']
# http,feeds,feedburner,com , ['NonArts']
# feeds,feedburner,com,alltribstories , ['NonArts']
# http,psidonline,isr,umich , ['NonArts']
# psidonline,isr,umich,edu , ['NonArts']
# http,www,journalismjobs,com , ['NonArts']
# http,www,winnipegfreepress,com , ['NonArts']
# http,www,cunacouncils,org , ['NonArts']
# http,www,patralekhachatterjee,com , ['NonArts']
# http,geocities,com,dhdeans , ['NonArts']
# geocities,com,dhdeans,portfolio , ['NonArts']
# http,www,times,standard , ['NonArts']
# www,times,standard,com , ['NonArts']
# http,www,centralohio,com , ['NonArts']
# http,www,vcpa,com , ['NonArts']
# www,vcpa,com,au , ['NonArts']
# vcpa,com,au,index , ['NonArts']
# com,au,index,php , ['NonArts']
# au,index,php,option , ['NonArts']
# index,php,option,com , ['NonArts']
# php,option,com,co , ['NonArts']
# http,feeds,wsjonline,com , ['NonArts']
# feeds,wsjonline,com,wsj , ['NonArts']
# wsjonline,com,wsj,numbersguy , ['NonArts']
# com,wsj,numbersguy,feed , ['NonArts']
# http,www,timbullard,com , ['NonArts']
# http,www,hola,arkansas , ['NonArts']
# www,hola,arkansas,com , ['NonArts']
# http,www,mykawartha,com , ['NonArts']
# http,www,fauxnewschannel,com , ['NonArts']
# http,www,marshillonline,com , ['NonArts']
# http,www,bramfoto,com , ['NonArts']
# http,www,therip,com , ['NonArts']
# http,www,cordweekly,com , ['NonArts']
# http,www,chandigarhpressclub,com , ['NonArts']
# http,www,rediff,com , ['NonArts']
# www,rediff,com,news , ['NonArts']
# rediff,com,news,coverage , ['NonArts']
# com,news,coverage,html , ['NonArts']
# http,www,un,org , ['NonArts']
# www,un,org,news , ['NonArts']
# http,www,madhunt,com , ['NonArts']
# http,www,loonnews,com , ['NonArts']
# http,www,essexstudent,com , ['NonArts']
# www,essexstudent,com,student , ['NonArts']
# essexstudent,com,student,media , ['NonArts']
# com,student,media,the , ['NonArts']
# http,www,hedricksmith,com , ['NonArts']
# www,hedricksmith,com,pbsdoc , ['NonArts']
# hedricksmith,com,pbsdoc,survivingth , ['NonArts']
# http,www,timsnopek,com , ['NonArts']
# http,www,registerguard,com , ['NonArts']
# http,www,hamline,edu , ['NonArts']
# www,hamline,edu,oracle , ['NonArts']
# hamline,edu,oracle,index , ['NonArts']
# edu,oracle,index,xml , ['NonArts']
# http,www,theorigby,com , ['NonArts']
# http,feeds,cbsnews,com , ['NonArts']
# feeds,cbsnews,com,cbsnewsmain , ['NonArts']
# cbsnews,com,cbsnewsmain,format , ['NonArts']
# com,cbsnewsmain,format,xml , ['NonArts']
# http,www,winnipegfirst,ca , ['NonArts']
# http,www,webujournal,com , ['NonArts']
# http,www,thebraziltimes,com , ['NonArts']
# http,www,portagedailygraphic,com , ['NonArts']
# http,www,heartland,org , ['NonArts']
# www,heartland,org,article , ['NonArts']
# heartland,org,article,cfm , ['NonArts']
# org,article,cfm,artid , ['NonArts']
# http,www,epra,org , ['NonArts']
# http,www,shakopeenews,com , ['NonArts']
# http,www,californiaaggie,com , ['NonArts']
# http,www,alligator,org , ['NonArts']
# http,www,pbs,org , ['NonArts']
# www,pbs,org,newshour , ['NonArts']
# pbs,org,newshour,rss , ['NonArts']
# org,newshour,rss,weather , ['NonArts']
# newshour,rss,weather,xml , ['NonArts']
# http,www,weather,com , ['NonArts']
# http,www,uweekly,com , ['NonArts']
# http,hotzone,yahoo,com , ['NonArts']
# http,www,wordgames,co , ['NonArts']
# www,wordgames,co,uk , ['NonArts']
# http,www,delrionewsherald,com , ['NonArts']
# http,broadcast,live,com , ['NonArts']
# broadcast,live,com,radionews , ['NonArts']
# live,com,radionews,html , ['NonArts']
# http,packetonline,com,hopewell , ['NonArts']
# packetonline,com,hopewell,valley , ['NonArts']
# com,hopewell,valley,news , ['NonArts']
# hopewell,valley,news,f , ['NonArts']
# http,www,newsparadise,com , ['NonArts']
# http,www,the,weekly , ['NonArts']
# www,the,weekly,net , ['NonArts']
# http,www,dixieweb,com , ['NonArts']
# http,www,florala,net , ['NonArts']
# www,florala,net,articles , ['NonArts']
# florala,net,articles,rss , ['NonArts']
# http,www,starcourier,com , ['NonArts']
# http,www,theinfosage,com , ['NonArts']
# http,www,hilite,org , ['NonArts']
# http,astronomylinks,com,astrowire , ['NonArts']
# astronomylinks,com,astrowire,htm , ['NonArts']
# http,www,thenewsherald,com , ['NonArts']
# http,www,thehappyguy,com , ['NonArts']
# www,thehappyguy,com,positive , ['NonArts']
# thehappyguy,com,positive,thinking , ['NonArts']
# com,positive,thinking,f , ['NonArts']
# http,www,mitchellnews,com , ['NonArts']
# http,www,championnewspapers,com , ['NonArts']
# http,www,picture,newsletter , ['NonArts']
# www,picture,newsletter,com , ['NonArts']
# http,radio,weblogs,com , ['NonArts']
# radio,weblogs,com,rss , ['NonArts']
# weblogs,com,rss,xml , ['NonArts']
# http,www,journalism,umd , ['NonArts']
# www,journalism,umd,edu , ['NonArts']
# http,www,theapp,appstate , ['NonArts']
# www,theapp,appstate,edu , ['NonArts']
# http,www,minkindesign,com , ['NonArts']
# www,minkindesign,com,photo , ['NonArts']
# http,www,ncbr,com , ['NonArts']
# http,www,angelfire,com , ['NonArts']
# www,angelfire,com,ks , ['NonArts']
# angelfire,com,ks,greatdebate , ['NonArts']
# http,www,columbiadailyherald,com , ['NonArts']
# http,www,idixon,com , ['NonArts']
# http,cacklinggrackle,blogspot,com , ['NonArts']
# http,www,hillsbororeporter,com , ['NonArts']
# http,www,hutchnews,com , ['NonArts']
# http,www,americandaily,com , ['NonArts']
# http,www,bobbrooke,com , ['NonArts']
# http,www,laloyolan,com , ['NonArts']
# http,www,pressclub,alaskawriters , ['NonArts']
# www,pressclub,alaskawriters,com , ['NonArts']
# http,www,magazine,utoronto , ['NonArts']
# www,magazine,utoronto,ca , ['NonArts']
# http,www,michaelcoyne,com , ['NonArts']
# www,michaelcoyne,com,au , ['NonArts']
# http,www,scottishbanner,com , ['NonArts']
# http,www,honoluluadvertiser,com , ['NonArts']
# http,haasweek,berkeley,edu , ['NonArts']
# http,www,almaguinnews,com , ['NonArts']
# http,trinicenter,com,bukkarennie , ['NonArts']
# http,www,floydpress,com , ['NonArts']
# http,www,dailyliberal,com , ['NonArts']
# www,dailyliberal,com,au , ['NonArts']
# http,www,navajohopiobserver,com , ['NonArts']
# http,www,monroenews,com , ['NonArts']
# http,www,news,com , ['NonArts']
# www,news,com,au , ['NonArts']
# http,www,kirklapointe,com , ['NonArts']
# http,www,nnsl,com , ['NonArts']
# http,www,atomictonic,com , ['NonArts']
# http,www,brianpobuda,com , ['NonArts']
# http,www,unews,com , ['NonArts']
# http,www,charlestonbusiness,com , ['NonArts']
# http,www,waynecojournalbanner,com , ['NonArts']
# http,www,accuracy,org , ['NonArts']
# http,users,skynet,be , ['NonArts']
# users,skynet,be,phicarly , ['NonArts']
# http,www,vcpa,com , ['NonArts']
# www,vcpa,com,au , ['NonArts']
# vcpa,com,au,index , ['NonArts']
# com,au,index,php , ['NonArts']
# au,index,php,option , ['NonArts']
# index,php,option,com , ['NonArts']
# php,option,com,co , ['NonArts']
# http,www,lesley,edu , ['NonArts']
# www,lesley,edu,lesleytoday , ['NonArts']
# lesley,edu,lesleytoday,index , ['NonArts']
# edu,lesleytoday,index,html , ['NonArts']
# http,chico,nss,udel , ['NonArts']
# chico,nss,udel,edu , ['NonArts']
# nss,udel,edu,udaily , ['NonArts']
# http,www,mab,org , ['NonArts']
# http,www,tornadotimes,com , ['NonArts']
# http,www,ajn,com , ['NonArts']
# www,ajn,com,au , ['NonArts']
# http,www,haleakalatimes,com , ['NonArts']
# http,www,brainerddispatch,com , ['NonArts']
# http,www,menarebetterthanwomen,com , ['NonArts']
# http,www,timbomb,net , ['NonArts']
# http,www,dareland,com , ['NonArts']
# www,dareland,com,index , ['NonArts']
# dareland,com,index,html , ['NonArts']
# http,www,agoudjian,com , ['NonArts']
# www,agoudjian,com,galerie , ['NonArts']
# agoudjian,com,galerie,en , ['NonArts']
# com,galerie,en,html , ['NonArts']
# http,www,pbs,org , ['NonArts']
# www,pbs,org,newshour , ['NonArts']
# pbs,org,newshour,media , ['NonArts']
# http,www,chelsearecord,com , ['NonArts']
# http,www,npr,org , ['NonArts']
# www,npr,org,programs , ['NonArts']
# http,channels,netscape,com , ['NonArts']
# channels,netscape,com,info , ['NonArts']
# netscape,com,info,internationa , ['NonArts']
# http,www,newsnow,co , ['NonArts']
# www,newsnow,co,uk , ['NonArts']
# newsnow,co,uk,services , ['NonArts']
# http,www,theexpressnewspaper,com , ['NonArts']
# http,www,euronews,net , ['NonArts']
# http,www,menuez,com , ['NonArts']
# http,www,mexicoledger,com , ['NonArts']
# http,www,yourdailyjournal,com , ['NonArts']
# http,www,exile,ru , ['NonArts']
# http,www,guylittle,com , ['NonArts']
# www,guylittle,com,au , ['NonArts']
# guylittle,com,au,index , ['NonArts']
# com,au,index,html , ['NonArts']
# http,www,celtic,connection , ['NonArts']
# www,celtic,connection,com , ['NonArts']
# http,www,jpost,com , ['NonArts']
# www,jpost,com,servlet , ['NonArts']
# jpost,com,servlet,satellite , ['NonArts']
# com,servlet,satellite,pagenam , ['NonArts']
# http,www,nytimes,com , ['NonArts']
# http,public,wartburg,edu , ['NonArts']
# public,wartburg,edu,trumpet , ['NonArts']
# http,www,sgst,com , ['NonArts']
# www,sgst,com,au , ['NonArts']
# http,www,deutschermichel,com , ['NonArts']
# http,www,cananews,net , ['NonArts']
# http,www,devilslakejournal,com , ['NonArts']
# http,www,guardian,co , ['NonArts']
# www,guardian,co,uk , ['NonArts']
# guardian,co,uk,world , ['NonArts']
# co,uk,world,rss , ['NonArts']
# http,www,nla,gov , ['NonArts']
# www,nla,gov,au , ['NonArts']
# nla,gov,au,ferg , ['NonArts']
# gov,au,ferg,issn , ['NonArts']
# au,ferg,issn,html , ['NonArts']
# http,members,ozemail,com , ['NonArts']
# members,ozemail,com,au , ['NonArts']
# ozemail,com,au,ddpphoto , ['NonArts']
# http,www,mediauk,com , ['NonArts']
# http,www,srtv,on , ['NonArts']
# www,srtv,on,ca , ['NonArts']
# http,www,mediaaccess,org , ['NonArts']
# www,mediaaccess,org,programs , ['NonArts']
# mediaaccess,org,programs,lpfm , ['NonArts']
# org,programs,lpfm,index , ['NonArts']
# http,www,opinionjournal,com , ['NonArts']
# http,www,efluxmedia,com , ['NonArts']
# http,shamed,blogspot,com , ['NonArts']
# http,www,mixeye,com , ['NonArts']
# http,www,triggernews,com , ['NonArts']
# http,www,wyandottewest,com , ['NonArts']
# http,www,imogenmatthews,co , ['NonArts']
# www,imogenmatthews,co,uk , ['NonArts']
# http,www,centralchronicle,com , ['NonArts']
# http,www,vcpa,com , ['NonArts']
# www,vcpa,com,au , ['NonArts']
# vcpa,com,au,index , ['NonArts']
# com,au,index,php , ['NonArts']
# au,index,php,option , ['NonArts']
# index,php,option,com , ['NonArts']
# php,option,com,co , ['NonArts']
# http,www,callielipkin,com , ['NonArts']
# http,www,flatheadbeacon,com , ['NonArts']
# http,www,statesman,com , ['NonArts']
# http,www,irishexaminer,com , ['NonArts']
# www,irishexaminer,com,breaking , ['NonArts']
# http,www,geocities,com , ['NonArts']
# www,geocities,com,nationalliar , ['NonArts']
# http,braidwood,yourguide,com , ['NonArts']
# braidwood,yourguide,com,au , ['NonArts']
# http,www,newslookup,com , ['NonArts']
# http,www,zwire,com , ['NonArts']
# www,zwire,com,site , ['NonArts']
# zwire,com,site,news , ['NonArts']
# com,site,news,cfm , ['NonArts']
# site,news,cfm,brd , ['NonArts']
# http,www,citsu,com , ['NonArts']
# www,citsu,com,publications , ['NonArts']
# citsu,com,publications,index , ['NonArts']
# com,publications,index,html , ['NonArts']
# http,www,rcreader,com , ['NonArts']
# http,www,starnewsgroup,com , ['NonArts']
# www,starnewsgroup,com,au , ['NonArts']
# starnewsgroup,com,au,star , ['NonArts']
# com,au,star,dandenong , ['NonArts']
# http,www,virginiastar,net , ['NonArts']
# http,www,ivymags,com , ['NonArts']
# http,www,jasonoffutt,com , ['NonArts']
# http,www,paisano,online , ['NonArts']
# www,paisano,online,com , ['NonArts']
# http,www,insideworld,com , ['NonArts']
# http,www,trentarthur,ca , ['NonArts']
# http,www,buffaloreflex,com , ['NonArts']
# http,www,defence,gov , ['NonArts']
# www,defence,gov,au , ['NonArts']
# defence,gov,au,news , ['NonArts']
# gov,au,news,navynews , ['NonArts']
# http,www,lornacollier,com , ['NonArts']
# http,www,morrisdailyherald,com , ['NonArts']
# http,www,mediapost,com , ['NonArts']
# http,www,chadlsmith,com , ['NonArts']
# http,www,therconline,com , ['NonArts']
# http,www,whofailedtoday,com , ['NonArts']
# http,www,newyorkpressclub,org , ['NonArts']
